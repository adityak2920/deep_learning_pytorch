# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import skimage.io as io
import pandas as pd

# %%
im=cv2.imread("/Users/adityakumar/Downloads/IMG_20171008_162636.jpg")
img=cv2.cvtColor(im, cv2.COLOR_RGB2GRAY)
print(img.shape)
img=cv2.resize(img, (650, 450))
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# (1944, 2592)

# %%
kernel=np.array([[-1., -1.25, -1.],
                   [-1.25, 9.0, -1.25],
                   [-1., -1.25, -1.]])
print(kernel)
# Out:
# [[-1.   -1.25 -1.  ]
#  [-1.25  9.   -1.25]
#  [-1.   -1.25 -1.  ]]

# %%
new_image=np.zeros((img.shape[0]-kernel.shape[0]+1,img.shape[1]-kernel.shape[1]+1))
print(new_image.shape)
# Out:
# (448, 648)

# %%
#convolution
for ix in range(new_image.shape[0]):
    for iy in range(new_image.shape[1]):
        patch=img[ix:ix+kernel.shape[0], iy:iy+kernel.shape[1]]
        prod=patch*kernel
        
        new_image[ix,iy]=max(0,prod.sum())

# %%
plt.imshow(new_image, cmap='gray')
